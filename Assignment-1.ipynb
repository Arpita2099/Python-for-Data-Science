# %%
print("Welcome to Data Analysis with Python Course")
# Out:
# Welcome to Data Analysis with Python Course

# %%
print("Hello and Welcome to first day python code to Arpita Sah.")
# Out:
# Hello and Welcome to first day python code to Arpita Sah.
