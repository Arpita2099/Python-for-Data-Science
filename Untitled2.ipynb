# %%
# SEABORN-->Advanced ploting library that sits on top of matplolib based on Hierarchy.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
tips=sns.load_dataset("tips")
print(tips.head())
print(tips.info())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
sna.scatterplot()

# %%
sns.barplot(data = tips, x= 'day', y= 'tip', errorbar= None, hue= 'sex', palette= "coolwarm")
# palette can be 'colorblind','coolwarm','roket','dark','pastel','bright','muted'
plt.show()

# %%
sns.histplot(data=tips, x='total_bill',hue='smoker', multiple='stack', bins=20)
plt.show()

# %%
sns.histplot(data=tips, x='total_bill',hue='sex', multiple='stack', bins=20, kde= True)
# Kernel desity estimation.
# Analyze the trend and determine whether Right skewed or lef skewed or normal distribution.
# Sometimes there are multiple peaks, in that case skewness is not 
plt.show()

# %%
# Scatterplots
sns.scatterplot(data=tips, x='total_bill', y='tip')
plt.xlabel("Total bill")
plt.ylabel("Tip left")
plt.title("Scatter plot of Trips")
plt.show()

# %%
# Scatterplots
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='time')
plt.xlabel("Total bill")
plt.ylabel("Tip left")
plt.title("Scatter plot of Trips")
plt.show()

# %%
# Scatterplots
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='sex')
plt.xlabel("Total bill")
plt.ylabel("Tip left")
plt.title("Scatter plot of Trips")
plt.show()

# %%
# Scatterplots
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='sex', size='size', style='day')
plt.xlabel("Total bill")
plt.ylabel("Tip left")
plt.title("Scatter plot of Trips")
plt.show()

# %%
fmri=sns.load_dataset("fmri")
print(fmri)
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
# Line 
sns.lineplot(data=fmri, x="timepoint", y="signal", errorbar=None, hue='event', style="region")
plt.xlabel("Time Plot")
plt.ylabel("Signal Receive")
plt.title("The Relation between Timeplot and Signal.")
plt.show()

# %%
# Line 
sns.lineplot(data=fmri, x="timepoint", y="signal")
plt.show()
