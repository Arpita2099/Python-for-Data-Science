# %%
# Assignment
import pandas as pd # It import pandas as pd
import numpy as np # It import numpy as np
import matplotlib.pyplot as plt # It import matplotlib.pyplot as plt

# Step 1: Create the dataset (C++ has missing value NaN)
data = {
    "Programming Language": ["Java", "Python", "PHP", "JavaScript", "C#", "C++"],
    "Popularity": [22.2, 17.6, 8.8, 8.0, 7.7, np.nan] # np.nan used to show the 
                                                    # value of C++ is NaN(missing) 
}

# Create DataFrame
df = pd.DataFrame(data)

# %%
# a. Pandas: Find missing data and output in Boolean
print("Missing Data in Popularity Column:")
print(df.isnull().any())
print(df["Popularity"].isnull())
# Out:
# Missing Data in Popularity Column:
# Programming Language    False
# Popularity               True
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# Name: Popularity, dtype: bool

# %%
print("Missing Data in Popularity Column:")
print(df["Popularity"].isnull().any())
# Out:
# Missing Data in Popularity Column:
# True

# %%
print(df)
# Out:
#   Programming Language  Popularity
# 0                 Java        22.2
# 1               Python        17.6
# 2                  PHP         8.8
# 3           JavaScript         8.0
# 4                   C#         7.7
# 5                  C++         NaN

# %%
# b. NumPy: Add missing value 6.7 for C++ and update JavaScript to 8.3
df.loc[df["Programming Language"] == "C++", "Popularity"] = 6.7
df.loc[df["Programming Language"] == "JavaScript", "Popularity"] = 8.3
print("\nUpdated DataFrame:")
print(df)
# Out:
# Updated DataFrame:
#   Programming Language  Popularity
# 0                 Java        22.2
# 1               Python        17.6
# 2                  PHP         8.8
# 3           JavaScript         8.3
# 4                   C#         7.7
# 5                  C++         6.7

# %%
# c. Matplotlib: Display bar chart
plt.figure(figsize=(8, 5))
plt.bar(df["Programming Language"], df["Popularity"], color="skyblue", edgecolor="black")
plt.title("Programming Language Popularity")
plt.xlabel("Programming Languages")
plt.ylabel("Popularity (%)")
plt.show()
