# %%
with open('PracticeWorkShop1.txt','r') as file:
    doc=file.read()

# %%
doc
# Out:
# 'Once upon a time, there was a very curious cat and doting dog who lived together in a cozy house next to a meadow. The cat\'s name was Lulu and the dog\'s name was Duke.\nEvery night, Lulu and Duke would tell each other stories before they went to sleep, which they would conjure up with their imaginations.\n\nOne night, while they were snuggled up in bed together, Duke asked Lulu to tell him a story about cats and dogs living together in harmony.\n\nLulu thought for a moment before she began her story: "Once upon a time, there were two cats and two dogs who lived in the same house, but never talked to each other."\n\n"One day," continued Lulu, "the cats decided that it was time for them to get to know the dogs better so they could all live together peacefully."\n\nSo the cats invited the dogs over for dinner and the four of them sat down at the table together for what seemed like an eternity of awkward silence until one of the cats broke it by asking the other cat what she had been 
# ...

# %%
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\arpit\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
import sklearn

# %%
tokens=nltk.word_tokenize(doc)

# %%
tokens[:10]
# Out:
# ['Once', 'upon', 'a', 'time', ',', 'there', 'was', 'a', 'very', 'curious']
